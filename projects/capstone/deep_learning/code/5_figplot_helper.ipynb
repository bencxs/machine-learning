# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('fin_9_mixed max avg pool_relu_l2 0.0005_lr 0.0005_5 conv_fc 512.csv', header=None)
df1 = pd.DataFrame(df1)

df2 = pd.read_csv('sensitivty_0.9.csv', header=None)
df2 = pd.DataFrame(df2)

df3 = pd.read_csv('sensitivty_0.8.csv', header=None)
df3 = pd.DataFrame(df3)

df4 = pd.read_csv('sensitivty_0.7.csv', header=None)
df4 = pd.DataFrame(df4)

df5 = pd.read_csv('opt_5_momentum_0.001.csv', header=None)
df5 = pd.DataFrame(df5)

df6 = pd.read_csv('opt_6_ftrl_0.9.csv', header=None)
df6 = pd.DataFrame(df6)

df7 = pd.read_csv('opt_7_rmsprop_0.001.csv', header=None)
df7 = pd.DataFrame(df7)

df8 = pd.read_csv('reg_8_L2 0.9_dropout 0.9.csv', header=None)
df8 = pd.DataFrame(df8)

df9 = pd.read_csv('reg_9_L2 0.9_dropout 0.5.csv', header=None)
df9 = pd.DataFrame(df9)

df10 = pd.read_csv('fin_1_mixed max avg pool_relu_lr 0.0005.csv', header=None)
df10 = pd.DataFrame(df10)

#df11 = pd.read_csv('fin_7_mixed max avg pool_elu_l2 0.0005_lr 0.0005_7 conv_fc 1024.csv.csv', header=None)
#df11 = pd.DataFrame(df11)

# %%
sns.set_style("ticks")
fig, ax = plt.subplots()

ax.plot(df1[0], df1[1], label='Train')
ax.plot(df1[0], df1[2], label='Valid')
#ax.plot(df2[0], df2[2], label='Valid - 90%')
#ax.plot(df3[0], df3[2], label='Valid - 80%')
#ax.plot(df4[0], df4[2], label='Valid - 70%')
#ax.plot(df1[0], df10[2], label='Valid - ReLU')
#ax.plot(df2[0], df2[1], label='Train - 90%')
#ax.plot(df11[0], df11[2], label='Valid - ELU')
#ax.plot(df3[0], df3[1], label='Train - 80%')
#ax.plot(df4[0], df4[1], label='Train - 70%')
ax.set_xlabel('Training steps')
ax.set_ylabel('Accuracy (%)')
#ax.set_ylim([80,100])
ax.set_title('Learning Curve')
ax.legend(loc=4)
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(df11[0], df11[1], label='Train')
ax.plot(df11[0], df11[2], label='Valid')
ax.set_xlabel('Training steps')
ax.set_ylabel('Accuracy (%)')
ax.set_ylim([0,100])
ax.set_title('Learning Curve')
ax.legend(loc=4)
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(df9[0], df9[1], label='Train')
ax.plot(df9[0], df9[2], label='Valid')
ax.set_xlabel('Training steps')
ax.set_ylabel('Accuracy (%)')
ax.set_ylim([0,100])
ax.set_title('Learning Curve - L2 0.9, Dropout 0.5')
ax.legend(loc=4)
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(df1[0], df1[1], label='Train - Baseline')
ax.plot(df1[0], df1[2], label='Valid - Baseline')
#ax.plot(df2[0], df2[1], label='Train - L2 0.9 Dropout 0.9')
#ax.plot(df2[0], df2[2], label='Valid - L2 0.9 Dropout 0.9')
#ax.plot(df3[0], df3[1], label='Train - L2 0.9 Dropout 0.5')
#ax.plot(df3[0], df3[2], label='Valid - L2 0.9 Dropout 0.5')
#ax.plot(df4[0], df4[1], label='Train - L2 0.0005 Dropout 0.5')
#ax.plot(df4[0], df4[2], label='Valid - L2 0.0005 Dropout 0.5')
ax.set_xlabel('Training steps')
ax.set_ylabel('Accuracy (%)')
ax.set_ylim([0,100])
ax.set_title('Learning Curve')
ax.legend(loc=4)
plt.show()

# %%
plt.plot(df1[0], df1[3])
#plt.plot(df2[0], df2[3], label="90%")
#plt.plot(df3[0], df3[3], label="80%")
#plt.plot(df4[0], df4[3], label="70%")
#plt.plot(df5[0], df5[3], label="Momentum")
#plt.plot(df6[0], df6[3], label="Ftrl")
#plt.plot(df7[0], df7[3], label="RMSProp")
#plt.plot(df8[0], df8[3], label="L2 0.9, Dropout 0.9")
#plt.plot(df9[0], df9[3], label="L2 0.9, Dropout 0.5")
#plt.plot(df10[0], df10[3], label="ReLU")
#plt.plot(df11[0], df11[3], label="Mixed Max-Avg, ELU, 7 Conv")
plt.xlabel('Training steps')
plt.ylabel('Loss')
#plt.ylim([0,2])
#plt.xlim([25000,30000])
plt.title('Cross Entropy')
plt.legend(loc=1)
plt.show()
